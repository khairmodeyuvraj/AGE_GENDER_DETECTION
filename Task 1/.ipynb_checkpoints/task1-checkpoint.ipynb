# %% [markdown]
# **import required libraries**

# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.preprocessing.image import load_img
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
from keras.callbacks import LearningRateScheduler
from PIL import Image
from tensorflow.keras.utils import plot_model
from pathlib import Path
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.keras.layers import Dropout, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
import warnings
warnings.filterwarnings("ignore", message=".*CuDNN.*")
warnings.filterwarnings("ignore", message=".*cuFFT.*")
warnings.filterwarnings("ignore", message=".*cuBLAS.*")
import os
from tensorflow.keras import utils
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import datasets, layers, models
from PIL import Image

# %% [markdown]
# **load the dataset**

# %%
# Dataset Path
# Current folder (Task 1)
CURRENT_DIR = os.getcwd()

# Go one level up to project root
BASE_DIR = os.path.dirname(CURRENT_DIR)

# Dataset folder in root
DATASET_PATH = os.path.join(BASE_DIR, "Datasets", "UTKFace")

BASE_DIRS = [DATASET_PATH]

print("Dataset Path:", DATASET_PATH)
# Out:
# Dataset Path: C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\UTKFace

# %%
# Read Dataset Images
image_paths = []
age_labels = []
gender_paths = []

for BASE_DIR in BASE_DIRS:

    for filename in tqdm(os.listdir(BASE_DIR)):

        temp = filename.split('_')

        if temp[0].isdigit():

            age = int(temp[0])
            gender = int(temp[1])

            image_path = os.path.join(BASE_DIR, filename)

            image_paths.append(image_path)
            age_labels.append(age)
            gender_paths.append(gender)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 23708/23708 [00:00<00:00, 131919.69it/s]

# %%
# Create DataFrame for easy data handling
df = pd.DataFrame()

df['image'] = image_paths
df['age'] = age_labels
df['gender'] = gender_paths

print("Dataset Shape:", df.shape)
print(df.head())
# Out:
# Dataset Shape: (23708, 3)
#                                                image  age  gender
# 0  C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\U...  100       0
# 1  C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\U...  100       0
# 2  C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\U...  100       1
# 3  C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\U...  100       1
# 4  C:\Users\yuvra\AGE_GENDER_DETECTION\Datasets\U...  100       1

# %%
# Gender dictionary for readable output
gender_dict = {0:'Male',1:'Female'}

# %%
# Display sample image from dataset
img = Image.open(df['image'][0])
plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# **Visualize Age Distribution in Dataset**

# %%
sns.displot(df['age'], kde=True, bins=30)

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# **Feature Extraction Function**

# %%
def extract_feature(images):

    features = []

    for image in tqdm(images):

        img = Image.open(image).convert('L')
        
        # Convert images to grayscale and resize to 128x128
        img = img.resize((128,128), Image.BILINEAR)

        img = np.array(img)

        features.append(img)

    features = np.array(features)

    features = features.reshape(len(features),128,128,1)

    return features

# %%
X = extract_feature(df['image'])

print("X shape:", X.shape)

# Normalize pixel values
X = X / 255.0
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 23708/23708 [04:39<00:00, 84.76it/s]
# X shape: (23708, 128, 128, 1)

# %%
# Labels
y_gender = np.array(df['gender'])
y_age = np.array(df['age'])

print("Gender label shape:", y_gender.shape)
print("Age label shape:", y_age.shape)
# Out:
# Gender label shape: (23708,)
# Age label shape: (23708,)

# %% [markdown]
# **CNN Model Architecture**

# %%
input_shape = (128,128,1)

inputs = Input(input_shape)

conv1 = Conv2D(32,(3,3),activation='relu')(inputs)
maxp1 = MaxPooling2D((2,2))(conv1)

conv2 = Conv2D(64,(3,3),activation='relu')(maxp1)
maxp2 = MaxPooling2D((2,2))(conv2)

conv3 = Conv2D(128,(3,3),activation='relu')(maxp2)
maxp3 = MaxPooling2D((2,2))(conv3)

conv4 = Conv2D(256,(3,3),activation='relu')(maxp3)
maxp4 = MaxPooling2D((2,2))(conv4)

flatten = Flatten()(maxp4)

dense1 = Dense(256,activation='relu')(flatten)
dense2 = Dense(256,activation='relu')(flatten)

dropout1 = Dropout(0.3)(dense1)
dropout2 = Dropout(0.3)(dense2)

# Gender Output
output1 = Dense(1,activation='sigmoid',name='gender_out')(dropout1)

# Age Output
output2 = Dense(1,activation='relu',name='age_out')(dropout2)

model = Model(inputs=inputs,outputs=[output1,output2])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 128, 128, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 126, 126, 32)      │             320 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 63, 63, 32)        │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 61, 61, 64)        │          18,496 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 30, 30, 64)        │               0 │ conv2d_1[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 28, 28, 128)       │          73,856 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 14, 14, 128)       │               0 │ conv2d_2[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 12, 12, 256)       │         295,168 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 6, 6, 256)         │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 9216)              │               0 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 256)               │       2,359,552 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 256)               │       2,359,552 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 256)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 256)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gender_out (Dense)            │ (None, 1)                 │             257 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ age_out (Dense)               │ (None, 1)                 │             257 │ dropout_1[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 5,107,458 (19.48 MB)
#  Trainable params: 5,107,458 (19.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train Test Split**

# %%
y_combined = np.column_stack((y_gender,y_age))

X_train,X_temp,y_train_combined,y_temp_combined = train_test_split(
    X,y_combined,test_size=0.2,random_state=42
)

X_test,X_val,y_test_combined,y_val_combined = train_test_split(
    X_temp,y_temp_combined,test_size=0.5,random_state=42
)

y_train_gender,y_train_age = y_train_combined[:,0],y_train_combined[:,1]
y_test_gender,y_test_age = y_test_combined[:,0],y_test_combined[:,1]
y_val_gender,y_val_age = y_val_combined[:,0],y_val_combined[:,1]

# %%
# Training Configuration
model_path = './best_model.keras'

checkpointer = ModelCheckpoint(
    filepath=model_path,
    monitor='val_gender_out_accuracy',
    verbose=1,
    mode='max',
    save_best_only=True
)

model.compile(
    loss=['binary_crossentropy','mae'],
    optimizer='adam',
    metrics=['accuracy','mae']
)

annealer = LearningRateScheduler(lambda x:1e-3*0.9**x)

# %% [markdown]
# **Train model**

# %%
history = model.fit(
    x=X_train,
    y=[y_train_gender, y_train_age],
    batch_size=128,
    epochs=30,
    validation_data=(X_val,[y_val_gender, y_val_age]),
    callbacks=[annealer, checkpointer]
)
# Out:
# Epoch 1/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 17.7780 - age_out_mae: 17.7781 - gender_out_accuracy: 0.5284 - gender_out_loss: 0.7448 - loss: 18.5230
# Epoch 1: val_gender_out_accuracy improved from None to 0.52256, saving model to ./best_model.keras
#
# Epoch 1: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - age_out_loss: 16.0370 - age_out_mae: 16.0545 - gender_out_accuracy: 0.5286 - gender_out_loss: 0.7095 - loss: 16.7641 - val_age_out_loss: 14.4421 - val_age_out_mae: 14.3694 - val_gender_out_accuracy: 0.5226 - val_gender_out_loss: 0.6885 - val_loss: 15.0579 - learning_rate: 0.0010
# Epoch 2/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 14.5226 - age_out_mae: 14.5227 - gender_out_accuracy: 0.5613 - gender_out_loss: 0.6775 - loss: 15.2002
# Epoch 2: val_gender_out_accuracy improved from 0.52256 to 0.73513, saving model to ./best_model.keras
#
# Epoch 2: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 336s 2s/step - age_out_loss: 14.1670 - age_out_mae: 14.1820 - gender_out_accuracy: 0.6115 - gender_out_loss: 0.6459 - loss: 14.8287 - val_age_out_loss: 12.3082 - val_age_out_mae: 12.2740 - val_gender_out_accuracy: 0.7351 - val_gender_out_loss: 0.5230 - val_loss: 12.7978 - learning_rate: 9.0000e-04
# Epoch 3/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 12.0145 - age_out_mae: 12.0146 - gender_out_accuracy: 0.7386 - gender_out_loss: 0.5311 - loss: 12.5457
# Epoch 3: val_gender_out_accuracy improved from 0.73513 to 0.78026, saving model to ./best_model.keras
#
# Epoch 3: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - age_out_loss: 11.8893 - age_out_mae: 11.9002 - gender_out_accuracy: 0.7546 - gender_out_loss: 0.5069 - loss: 12.4077 - val_age_out_loss: 10.7116 - val_age_out_mae: 10.7017 - val_gender_out_accuracy: 0.7803 - val_gender_out_loss: 0.4563 - val_loss: 11.1590 - learning_rate: 8.1000e-04
# Epoch 4/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 10.8231 - age_out_mae: 10.8231 - gender_out_accuracy: 0.7907 - gender_out_loss: 0.4493 - loss: 11.2725
# Epoch 4: val_gender_out_accuracy improved from 0.78026 to 0.80008, saving model to ./best_model.keras
#
# Epoch 4: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - age_out_loss: 10.4631 - age_out_mae: 10.4619 - gender_out_accuracy: 0.7935 - gender_out_loss: 0.4429 - loss: 10.9055 - val_age_out_loss: 11.5433 - val_age_out_mae: 11.5293 - val_gender_out_accuracy: 0.8001 - val_gender_out_loss: 0.4239 - val_loss: 11.9539 - learning_rate: 7.2900e-04
# Epoch 5/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 10.3518 - age_out_mae: 10.3519 - gender_out_accuracy: 0.8054 - gender_out_loss: 0.4160 - loss: 10.7679
# Epoch 5: val_gender_out_accuracy improved from 0.80008 to 0.82792, saving model to ./best_model.keras
#
# Epoch 5: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - age_out_loss: 9.9532 - age_out_mae: 9.9683 - gender_out_accuracy: 0.8069 - gender_out_loss: 0.4142 - loss: 10.3835 - val_age_out_loss: 9.4753 - val_age_out_mae: 9.4851 - val_gender_out_accuracy: 0.8279 - val_gender_out_loss: 0.3827 - val_loss: 9.8689 - learning_rate: 6.5610e-04
# Epoch 6/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 9.4079 - age_out_mae: 9.4078 - gender_out_accuracy: 0.8146 - gender_out_loss: 0.3931 - loss: 9.8009
# Epoch 6: val_gender_out_accuracy improved from 0.82792 to 0.83340, saving model to ./best_model.keras
#
# Epoch 6: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - age_out_loss: 9.3955 - age_out_mae: 9.3865 - gender_out_accuracy: 0.8175 - gender_out_loss: 0.3936 - loss: 9.7805 - val_age_out_loss: 8.7907 - val_age_out_mae: 8.7947 - val_gender_out_accuracy: 0.8334 - val_gender_out_loss: 0.3672 - val_loss: 9.1630 - learning_rate: 5.9049e-04
# Epoch 7/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.9775 - age_out_mae: 8.9774 - gender_out_accuracy: 0.8232 - gender_out_loss: 0.3833 - loss: 9.3608
# Epoch 7: val_gender_out_accuracy improved from 0.83340 to 0.84184, saving model to ./best_model.keras
#
# Epoch 7: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - age_out_loss: 8.9815 - age_out_mae: 8.9745 - gender_out_accuracy: 0.8262 - gender_out_loss: 0.3771 - loss: 9.3521 - val_age_out_loss: 9.3517 - val_age_out_mae: 9.3616 - val_gender_out_accuracy: 0.8418 - val_gender_out_loss: 0.3479 - val_loss: 9.7103 - learning_rate: 5.3144e-04
# Epoch 8/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.7375 - age_out_mae: 8.7374 - gender_out_accuracy: 0.8399 - gender_out_loss: 0.3591 - loss: 9.0965
# Epoch 8: val_gender_out_accuracy improved from 0.84184 to 0.85280, saving model to ./best_model.keras
#
# Epoch 8: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 364s 2s/step - age_out_loss: 8.5380 - age_out_mae: 8.5291 - gender_out_accuracy: 0.8398 - gender_out_loss: 0.3541 - loss: 8.8838 - val_age_out_loss: 8.9172 - val_age_out_mae: 8.9255 - val_gender_out_accuracy: 0.8528 - val_gender_out_loss: 0.3320 - val_loss: 9.2586 - learning_rate: 4.7830e-04
# Epoch 9/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.2880 - age_out_mae: 8.2881 - gender_out_accuracy: 0.8457 - gender_out_loss: 0.3460 - loss: 8.6341
# Epoch 9: val_gender_out_accuracy improved from 0.85280 to 0.85449, saving model to ./best_model.keras
#
# Epoch 9: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - age_out_loss: 8.3146 - age_out_mae: 8.3187 - gender_out_accuracy: 0.8467 - gender_out_loss: 0.3415 - loss: 8.6602 - val_age_out_loss: 7.8964 - val_age_out_mae: 7.8992 - val_gender_out_accuracy: 0.8545 - val_gender_out_loss: 0.3269 - val_loss: 8.2263 - learning_rate: 4.3047e-04
# Epoch 10/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 8.0850 - age_out_mae: 8.0851 - gender_out_accuracy: 0.8561 - gender_out_loss: 0.3274 - loss: 8.4125
# Epoch 10: val_gender_out_accuracy improved from 0.85449 to 0.86124, saving model to ./best_model.keras
#
# Epoch 10: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 375s 2s/step - age_out_loss: 7.9707 - age_out_mae: 7.9739 - gender_out_accuracy: 0.8554 - gender_out_loss: 0.3264 - loss: 8.3010 - val_age_out_loss: 7.7133 - val_age_out_mae: 7.7113 - val_gender_out_accuracy: 0.8612 - val_gender_out_loss: 0.3099 - val_loss: 8.0217 - learning_rate: 3.8742e-04
# Epoch 11/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.8504 - age_out_mae: 7.8504 - gender_out_accuracy: 0.8586 - gender_out_loss: 0.3216 - loss: 8.1720
# Epoch 11: val_gender_out_accuracy improved from 0.86124 to 0.87305, saving model to ./best_model.keras
#
# Epoch 11: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - age_out_loss: 7.8184 - age_out_mae: 7.8176 - gender_out_accuracy: 0.8593 - gender_out_loss: 0.3164 - loss: 8.1349 - val_age_out_loss: 7.7406 - val_age_out_mae: 7.7377 - val_gender_out_accuracy: 0.8730 - val_gender_out_loss: 0.3038 - val_loss: 8.0423 - learning_rate: 3.4868e-04
# Epoch 12/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.6296 - age_out_mae: 7.6296 - gender_out_accuracy: 0.8644 - gender_out_loss: 0.3039 - loss: 7.9335
# Epoch 12: val_gender_out_accuracy did not improve from 0.87305
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 346s 2s/step - age_out_loss: 7.5698 - age_out_mae: 7.5673 - gender_out_accuracy: 0.8669 - gender_out_loss: 0.3041 - loss: 7.8721 - val_age_out_loss: 7.5322 - val_age_out_mae: 7.5334 - val_gender_out_accuracy: 0.8705 - val_gender_out_loss: 0.2891 - val_loss: 7.8231 - learning_rate: 3.1381e-04
# Epoch 13/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.4568 - age_out_mae: 7.4568 - gender_out_accuracy: 0.8672 - gender_out_loss: 0.3008 - loss: 7.7575
# Epoch 13: val_gender_out_accuracy did not improve from 0.87305
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - age_out_loss: 7.4066 - age_out_mae: 7.4042 - gender_out_accuracy: 0.8710 - gender_out_loss: 0.2973 - loss: 7.6999 - val_age_out_loss: 7.4403 - val_age_out_mae: 7.4404 - val_gender_out_accuracy: 0.8730 - val_gender_out_loss: 0.2838 - val_loss: 7.7247 - learning_rate: 2.8243e-04
# Epoch 14/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.3142 - age_out_mae: 7.3142 - gender_out_accuracy: 0.8735 - gender_out_loss: 0.2884 - loss: 7.6026
# Epoch 14: val_gender_out_accuracy improved from 0.87305 to 0.87516, saving model to ./best_model.keras
#
# Epoch 14: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - age_out_loss: 7.2960 - age_out_mae: 7.2991 - gender_out_accuracy: 0.8759 - gender_out_loss: 0.2908 - loss: 7.5897 - val_age_out_loss: 8.0312 - val_age_out_mae: 8.0311 - val_gender_out_accuracy: 0.8752 - val_gender_out_loss: 0.2844 - val_loss: 8.3162 - learning_rate: 2.5419e-04
# Epoch 15/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.1370 - age_out_mae: 7.1369 - gender_out_accuracy: 0.8810 - gender_out_loss: 0.2737 - loss: 7.4106
# Epoch 15: val_gender_out_accuracy improved from 0.87516 to 0.88233, saving model to ./best_model.keras
#
# Epoch 15: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 344s 2s/step - age_out_loss: 7.1806 - age_out_mae: 7.1675 - gender_out_accuracy: 0.8782 - gender_out_loss: 0.2823 - loss: 7.4490 - val_age_out_loss: 7.3444 - val_age_out_mae: 7.3413 - val_gender_out_accuracy: 0.8823 - val_gender_out_loss: 0.2760 - val_loss: 7.6178 - learning_rate: 2.2877e-04
# Epoch 16/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - age_out_loss: 7.0969 - age_out_mae: 7.0970 - gender_out_accuracy: 0.8788 - gender_out_loss: 0.2810 - loss: 7.3780
# Epoch 16: val_gender_out_accuracy improved from 0.88233 to 0.88275, saving model to ./best_model.keras
#
# Epoch 16: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 2047s 14s/step - age_out_loss: 7.1683 - age_out_mae: 7.1715 - gender_out_accuracy: 0.8795 - gender_out_loss: 0.2790 - loss: 7.4510 - val_age_out_loss: 7.4571 - val_age_out_mae: 7.4464 - val_gender_out_accuracy: 0.8827 - val_gender_out_loss: 0.2699 - val_loss: 7.7169 - learning_rate: 2.0589e-04
# Epoch 17/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 7.1705 - age_out_mae: 7.1705 - gender_out_accuracy: 0.8850 - gender_out_loss: 0.2679 - loss: 7.4385
# Epoch 17: val_gender_out_accuracy improved from 0.88275 to 0.88317, saving model to ./best_model.keras
#
# Epoch 17: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - age_out_loss: 7.0328 - age_out_mae: 7.0358 - gender_out_accuracy: 0.8821 - gender_out_loss: 0.2709 - loss: 7.3074 - val_age_out_loss: 7.7164 - val_age_out_mae: 7.7200 - val_gender_out_accuracy: 0.8832 - val_gender_out_loss: 0.2670 - val_loss: 7.9874 - learning_rate: 1.8530e-04
# Epoch 18/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - age_out_loss: 7.0462 - age_out_mae: 7.0462 - gender_out_accuracy: 0.8806 - gender_out_loss: 0.2749 - loss: 7.3211
# Epoch 18: val_gender_out_accuracy did not improve from 0.88317
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 692s 5s/step - age_out_loss: 6.9697 - age_out_mae: 6.9655 - gender_out_accuracy: 0.8832 - gender_out_loss: 0.2710 - loss: 7.2366 - val_age_out_loss: 7.4433 - val_age_out_mae: 7.4483 - val_gender_out_accuracy: 0.8811 - val_gender_out_loss: 0.2749 - val_loss: 7.7242 - learning_rate: 1.6677e-04
# Epoch 19/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.8775 - age_out_mae: 6.8774 - gender_out_accuracy: 0.8890 - gender_out_loss: 0.2647 - loss: 7.1421
# Epoch 19: val_gender_out_accuracy improved from 0.88317 to 0.88697, saving model to ./best_model.keras
#
# Epoch 19: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - age_out_loss: 6.8448 - age_out_mae: 6.8352 - gender_out_accuracy: 0.8859 - gender_out_loss: 0.2648 - loss: 7.1006 - val_age_out_loss: 7.0885 - val_age_out_mae: 7.0860 - val_gender_out_accuracy: 0.8870 - val_gender_out_loss: 0.2630 - val_loss: 7.3493 - learning_rate: 1.5009e-04
# Epoch 20/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.7818 - age_out_mae: 6.7818 - gender_out_accuracy: 0.8846 - gender_out_loss: 0.2652 - loss: 7.0471
# Epoch 20: val_gender_out_accuracy did not improve from 0.88697
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - age_out_loss: 6.7723 - age_out_mae: 6.7713 - gender_out_accuracy: 0.8861 - gender_out_loss: 0.2621 - loss: 7.0337 - val_age_out_loss: 7.1390 - val_age_out_mae: 7.1329 - val_gender_out_accuracy: 0.8861 - val_gender_out_loss: 0.2605 - val_loss: 7.3938 - learning_rate: 1.3509e-04
# Epoch 21/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.6851 - age_out_mae: 6.6850 - gender_out_accuracy: 0.8925 - gender_out_loss: 0.2542 - loss: 6.9393
# Epoch 21: val_gender_out_accuracy improved from 0.88697 to 0.88781, saving model to ./best_model.keras
#
# Epoch 21: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - age_out_loss: 6.6757 - age_out_mae: 6.6642 - gender_out_accuracy: 0.8895 - gender_out_loss: 0.2590 - loss: 6.9234 - val_age_out_loss: 7.0533 - val_age_out_mae: 7.0459 - val_gender_out_accuracy: 0.8878 - val_gender_out_loss: 0.2623 - val_loss: 7.3092 - learning_rate: 1.2158e-04
# Epoch 22/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 6.7885 - age_out_mae: 6.7886 - gender_out_accuracy: 0.8913 - gender_out_loss: 0.2586 - loss: 7.0472
# Epoch 22: val_gender_out_accuracy did not improve from 0.88781
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - age_out_loss: 6.6864 - age_out_mae: 6.6940 - gender_out_accuracy: 0.8901 - gender_out_loss: 0.2559 - loss: 6.9506 - val_age_out_loss: 7.1000 - val_age_out_mae: 7.0939 - val_gender_out_accuracy: 0.8870 - val_gender_out_loss: 0.2566 - val_loss: 7.3511 - learning_rate: 1.0942e-04
# Epoch 23/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 6.5610 - age_out_mae: 6.5611 - gender_out_accuracy: 0.8899 - gender_out_loss: 0.2566 - loss: 6.8177
# Epoch 23: val_gender_out_accuracy improved from 0.88781 to 0.88823, saving model to ./best_model.keras
#
# Epoch 23: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - age_out_loss: 6.6033 - age_out_mae: 6.6049 - gender_out_accuracy: 0.8924 - gender_out_loss: 0.2535 - loss: 6.8580 - val_age_out_loss: 6.9955 - val_age_out_mae: 6.9921 - val_gender_out_accuracy: 0.8882 - val_gender_out_loss: 0.2617 - val_loss: 7.2539 - learning_rate: 9.8477e-05
# Epoch 24/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 6.5284 - age_out_mae: 6.5284 - gender_out_accuracy: 0.8947 - gender_out_loss: 0.2571 - loss: 6.7854
# Epoch 24: val_gender_out_accuracy improved from 0.88823 to 0.89161, saving model to ./best_model.keras
#
# Epoch 24: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - age_out_loss: 6.5475 - age_out_mae: 6.5361 - gender_out_accuracy: 0.8939 - gender_out_loss: 0.2536 - loss: 6.7895 - val_age_out_loss: 6.9548 - val_age_out_mae: 6.9545 - val_gender_out_accuracy: 0.8916 - val_gender_out_loss: 0.2595 - val_loss: 7.2142 - learning_rate: 8.8629e-05
# Epoch 25/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.6058 - age_out_mae: 6.6059 - gender_out_accuracy: 0.8970 - gender_out_loss: 0.2452 - loss: 6.8511
# Epoch 25: val_gender_out_accuracy did not improve from 0.89161
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 338s 2s/step - age_out_loss: 6.5268 - age_out_mae: 6.5340 - gender_out_accuracy: 0.8939 - gender_out_loss: 0.2531 - loss: 6.7851 - val_age_out_loss: 6.9292 - val_age_out_mae: 6.9299 - val_gender_out_accuracy: 0.8903 - val_gender_out_loss: 0.2537 - val_loss: 7.1842 - learning_rate: 7.9766e-05
# Epoch 26/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.4629 - age_out_mae: 6.4630 - gender_out_accuracy: 0.8969 - gender_out_loss: 0.2501 - loss: 6.7131
# Epoch 26: val_gender_out_accuracy did not improve from 0.89161
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 381s 2s/step - age_out_loss: 6.5329 - age_out_mae: 6.5403 - gender_out_accuracy: 0.8963 - gender_out_loss: 0.2486 - loss: 6.7890 - val_age_out_loss: 6.9347 - val_age_out_mae: 6.9324 - val_gender_out_accuracy: 0.8916 - val_gender_out_loss: 0.2524 - val_loss: 7.1853 - learning_rate: 7.1790e-05
# Epoch 27/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.4550 - age_out_mae: 6.4549 - gender_out_accuracy: 0.8926 - gender_out_loss: 0.2515 - loss: 6.7064
# Epoch 27: val_gender_out_accuracy did not improve from 0.89161
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 332s 2s/step - age_out_loss: 6.4843 - age_out_mae: 6.4708 - gender_out_accuracy: 0.8971 - gender_out_loss: 0.2449 - loss: 6.7155 - val_age_out_loss: 6.9029 - val_age_out_mae: 6.9027 - val_gender_out_accuracy: 0.8916 - val_gender_out_loss: 0.2517 - val_loss: 7.1549 - learning_rate: 6.4611e-05
# Epoch 28/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.4394 - age_out_mae: 6.4394 - gender_out_accuracy: 0.8990 - gender_out_loss: 0.2443 - loss: 6.6837
# Epoch 28: val_gender_out_accuracy did not improve from 0.89161
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 337s 2s/step - age_out_loss: 6.4573 - age_out_mae: 6.4560 - gender_out_accuracy: 0.8979 - gender_out_loss: 0.2439 - loss: 6.7004 - val_age_out_loss: 6.9557 - val_age_out_mae: 6.9522 - val_gender_out_accuracy: 0.8916 - val_gender_out_loss: 0.2544 - val_loss: 7.2073 - learning_rate: 5.8150e-05
# Epoch 29/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.4627 - age_out_mae: 6.4627 - gender_out_accuracy: 0.8967 - gender_out_loss: 0.2466 - loss: 6.7093
# Epoch 29: val_gender_out_accuracy improved from 0.89161 to 0.89203, saving model to ./best_model.keras
#
# Epoch 29: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 340s 2s/step - age_out_loss: 6.4379 - age_out_mae: 6.4280 - gender_out_accuracy: 0.8991 - gender_out_loss: 0.2439 - loss: 6.6721 - val_age_out_loss: 6.8981 - val_age_out_mae: 6.8982 - val_gender_out_accuracy: 0.8920 - val_gender_out_loss: 0.2501 - val_loss: 7.1488 - learning_rate: 5.2335e-05
# Epoch 30/30
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - age_out_loss: 6.4386 - age_out_mae: 6.4386 - gender_out_accuracy: 0.9003 - gender_out_loss: 0.2378 - loss: 6.6764
# Epoch 30: val_gender_out_accuracy improved from 0.89203 to 0.89372, saving model to ./best_model.keras
#
# Epoch 30: finished saving model to ./best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - age_out_loss: 6.4269 - age_out_mae: 6.4218 - gender_out_accuracy: 0.8968 - gender_out_loss: 0.2424 - loss: 6.6646 - val_age_out_loss: 6.8744 - val_age_out_mae: 6.8728 - val_gender_out_accuracy: 0.8937 - val_gender_out_loss: 0.2506 - val_loss: 7.1240 - learning_rate: 4.7101e-05

# %% [markdown]
# **Plot Accuracy**

# %%
plt.plot(history.history['gender_out_accuracy'])
plt.plot(history.history['val_gender_out_accuracy'])

plt.title('Gender Accuracy')
plt.legend(['train','validation'])

plt.show()

# %%
plt.plot(history.history['age_out_mae'])
plt.plot(history.history['val_age_out_mae'])

plt.title('Age Loss')
plt.legend(['train','validation'])

plt.show()

# %% [markdown]
# **Hair Detection Logic**

# %%
def detect_hair_type(image):

    hair_region = image[0:40,:]

    avg_intensity = np.mean(hair_region)

    if avg_intensity < 0.45:
        return "Long"
    else:
        return "Short"

# %%
# Example Prediction
image_index = 3000

print("Original Gender:", gender_dict[y_gender[image_index]])
print("Original Age:", y_age[image_index])


pred = model.predict(X[image_index].reshape(1,128,128,1))

pred_gender = gender_dict[int(round(pred[0][0][0]))]
pred_age = round(pred[1][0][0])


hair_type = detect_hair_type(X[image_index].reshape(128,128))


if 20 <= pred_age <= 30:

    if hair_type == "Long":
        pred_gender = "Female"
    else:
        pred_gender = "Male"


print("Predicted Gender:", pred_gender)
print("Predicted Age:", pred_age)
print("Hair Type:", hair_type)


plt.title(f'Gender:{pred_gender} Age:{pred_age} Hair:{hair_type}')
plt.imshow(X[image_index].reshape(128,128), cmap='gray')
plt.show()
# Out:
# Original Gender: Male
# Original Age: 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Predicted Gender: Male
# Predicted Age: 24
# Hair Type: Short

# %% [markdown]
# **Save the model**

# %%
# Current directory (Task 1)
CURRENT_DIR = os.getcwd()

# Go one level up → project root
PROJECT_ROOT = os.path.dirname(CURRENT_DIR)

# models folder in project root
models_dir = os.path.join(PROJECT_ROOT, "models")

# Create models folder if not exists
os.makedirs(models_dir, exist_ok=True)

# Final model path
model_path = os.path.join(models_dir, "Age_Sex_Detection.h5")

# Save model
model.save(model_path)

print("Model saved at:", model_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved at: C:\Users\yuvra\AGE_GENDER_DETECTION\models\Age_Sex_Detection.h5
